# %%
import os 
import sys 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import re
from collections import defaultdict
from IPython.display import display
import time

# %%
 
path="/home/c3/code/InfiniGen/wxd-test/results"
df =  pd.DataFrame({'dtype':[],'device':[],'seq_len':[],'dim':[],'ratio':[],'time':[]})
with open("sparse-fetch-efficienct.log", 'r') as lines:
    flag = '====================='
    new_row = {}
    
    for line in lines:
        if  flag  in line:
             continue 
             
                
                
        new_row = {}
              
        
        
        
        pairs = line.split(',')
        
        for pair in pairs:
            
            key,value = pair.split(":")
            if key=='time': value = float(value[:-3])
            if key=='dim': value = int(value)
            if key=='seq_len': value = int(value)
            if key=='ratio': value = float(value)
            new_row[key] = value 
        
        
            
        df.loc[len(df)] = new_row
df
# Out:
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 64
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 80
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 1000
# 128
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 64
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# 80
# 2000
# ...
